# %%
from model.env import Environment
import pandas as pd
from env.finance_env import FinanceEnv
from model.net import Net, DuelNet, TimeNet
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('data/nikkei.csv', index_col=0)
df = df[['Close']]
df['diff'] = df.diff()

for i in range(60):
    df[f'return_{i}'] = df['diff'].shift(i)
df = df.loc[~df.isnull().any(axis=1)]
df /= 1000                                      ##########工夫が必要########
#df['diff'].describe()

#df['Close'] = df['Close']/df['Close'].max()
df.drop(columns = ['diff'], inplace=True)
#df = df.iloc[:20000]
data = df.to_numpy()
return_data = df['return_0'].to_numpy()

# %%
env = Environment(FinanceEnv, data, return_data, TimeNet)
env.online_run()
# Out:
# ...
#   0%|▍                                                                              | 16/3360 [00:00<00:25, 131.15it/s]
# run type:cpu
# TimeNet(
#   (long): Linear(in_features=61, out_features=10, bias=True)
#   (long_mid): Linear(in_features=10, out_features=3, bias=True)
#   (middle): Linear(in_features=30, out_features=10, bias=True)
#   (middle_mid): Linear(in_features=10, out_features=3, bias=True)
#   (short): Linear(in_features=15, out_features=10, bias=True)
#   (short_mid): Linear(in_features=10, out_features=3, bias=True)
#   (out): Linear(in_features=11, out_features=3, bias=True)
# )
# ...
#  24%|███████████████████                                                            | 813/3360 [01:14<03:52, 10.96it/s]
# ...
# ...
#  98%|████████████████████████████████████████████████████████████████████████████  | 3278/3360 [05:05<00:08,  9.96it/s]

# %%
from model.util import calculate_index
calculate_index(env.reward_memory)
# Out:
# return_mean:-0.0006459366307441259
# return_std:0.019593210685027673
#  DD_mean:-0.00605828172157099
#  DD_std:0.012192884262286551
#  sharp_ratio:-0.03296737023492143
#  MDD:-0.18612313293945312
#  win_rate0.2226148409893993
#  Trade_Num:1038

# %%
plt.plot(df.Close.values)

# %%
env.online_run()
calculate_index(env.reward_memory)
# Out:
# ...
#  23%|██████████████████                                                             | 769/3360 [01:13<04:07, 10.48it/s]
# ...
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [05:26<00:00, 326.16s/it]
# return_mean:-0.04203028534869984
# return_std:0.09947714493004671
#  DD_mean:-0.06530814649435346
#  DD_std:0.1029678301842466
#  sharp_ratio:-0.422511978789258
#  MDD:-0.338960935703125
#  win_rate0.3076923076923077
#  Trade_Num:17

# %%
env.evaluation()
calculate_index(env.reward_memory)

# %%
df['Close'].iloc[:3000].values
# Out:
# array([0.80534306, 0.80528422, 0.80528422, ..., 0.79792868, 0.79792868,
#        0.79786984])

# %%
df.drop(columns = ['diff'], inplace=True)
df = df.iloc[:10000]
data = df.to_numpy()
return_data = df['return_0'].to_numpy()

# %%
from model.net import Net, DuelNet, TimeNet

env = Environment(FinanceEnv, data, return_data, Net)
# Out:
# Net(
#   (fc1): Linear(in_features=63, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
env.run()
env.plot_reward()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:32<00:00, 21.30s/it]

# %%
env.evaluation()
env.plot_reward()

# %%
normal_dqn = env.reward_memory

# %%
#proposed_dqn = env.reward_memory

# %%
plt.plot(normal_dqn, proposed_dqn)

# %%
import numpy as np
normal_dqn = np.array(normal_dqn).reshape(1,-1)
proposed_dqn - np.array(proposed_dqn).reshape(1,-1)
result = np.vstack([normal_dqn, proposed_dqn])

# %%
normal_dqn = normal_dqn.tolist()
proposed_dqn = proposed_dqn.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-ab2d2c6ec74a> in <module>
#       1 normal_dqn = normal_dqn.tolist()
# ----> 2 proposed_dqn = proposed_dqn.tolist()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
# Out:
# 0

# %%
normal_dqn = normal_dqn[0]
proposed_dqn = proposed_dqn[0]

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)
ax.plot(normal_dqn, label='base_dqn')
ax.plot(proposed_dqn, label='proposed_dqn')
ax.legend()

# %%
normal_dqn = np.array(normal_dqn)
normal_dqn.mean()/normal_dqn.std()
# Out:
# 2.1012757743218606

# %%
proposed_dqn = np.array(proposed_dqn)
proposed_dqn.mean()/proposed_dqn.std()
# Out:
# 1.0533711035404953

# %%
sample = normal_dqn[1:] - normal_dqn[:-1]
sample
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
sample.mean()/sample.std()
# Out:
# 0.05622816936225162

# %%
a = proposed_dqn[1:] - proposed_dqn[:-1]
a.mean()/a.std()
# Out:
# 0.07315054853199766

# %%
.std()
# Out:
# 0.05701068124970835

# %%
from model.env import Environment
import pandas as pd
from env.finance_env import FinanceEnv
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('data/AAPL.csv', index_col=0)
#df = df.iloc[:500]

return_data = df['close'].diff().fillna(0).to_numpy()
data = df[['close','macd','rsi_30','cci_30','dx_30']].to_numpy()
data = data/data.max(axis=0)
# data['close']は一番最初のカラムにする

# %%
# main クラス
env = Environment(FinanceEnv, data, return_data)
# Out:
# Net(
#   (fc1): Linear(in_features=7, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
env.run()
env.plot_reward()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 300/300 [18:16<00:00,  3.65s/it]

# %%
env.evaluation()
env.plot_reward()
# Out:
# tensor([[1.9042e-04, 5.9158e-06, 5.4363e-04]])
# tensor([[ 5.2854e-05, -1.3682e-03,  1.0852e-04]])
# tensor([[1.0771e-01, 1.0642e-01, 1.0148e-04]])
# tensor([[ 2.3089e-04,  3.2559e-05, -3.9836e-04]])
# tensor([[ 0.0002, -0.0885, -0.0888]])
# tensor([[ 0.0002, -0.1466, -0.1469]])
# tensor([[ 0.0003, -0.1790, -0.1793]])
# tensor([[ 3.3207e-04, -3.8236e-01, -3.8262e-01]])
# tensor([[ 3.6846e-04, -6.6370e-01, -6.6360e-01]])
# tensor([[ 3.2710e-04, -5.2369e-01, -5.2370e-01]])
# tensor([[ 3.1607e-04, -4.9595e-01, -4.9598e-01]])
# tensor([[ 3.1839e-04, -4.9662e-01, -4.9665e-01]])
# tensor([[ 3.1851e-04, -5.2568e-01, -5.2567e-01]])
# tensor([[ 3.3633e-04, -5.6994e-01, -5.6991e-01]])
# tensor([[ 3.6274e-04, -6.8749e-01, -6.8737e-01]])
# tensor([[ 3.9624e-04, -8.0372e-01, -8.0355e-01]])
# tensor([[ 4.4738e-04, -1.0203e+00, -1.0200e+00]])
# tensor([[ 4.7167e-04, -1.1557e+00, -1.1553e+00]])
# tensor([[ 4.9357e-04, -1.3274e+00, -1.3268e+00]])
# tensor([[ 4.5975e-04, -1.3756e+00, -1.3748e+00]])
# ...
